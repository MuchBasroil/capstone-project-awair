# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import RandomizedSearchCV,cross_val_score,train_test_split
from sklearn.preprocessing import MinMaxScaler,RobustScaler,StandardScaler
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error,classification_report

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout,BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import keras_tuner as kt
import tensorflow as tf
from tensorflow import python
from tensorflow import metrics

# %%
df = pd.read_csv(r'./dataset/air_quality_data_fix.csv')

# %%
df.head()
# Out:
#    latitude   longitude              dateTime regionCode  universal_aqi  \
# 0 -7.294524  112.732623  2024-11-24T08:00:00Z         id             26
# 1 -7.296518  112.639345  2024-11-24T08:00:00Z         id             19
# 2 -7.251514  112.759883  2024-11-24T08:00:00Z         id             38
# 3 -7.283691  112.745216  2024-11-24T08:00:00Z         id             30
# 4 -7.262437  112.721854  2024-11-24T08:00:00Z         id             30
#
#   universal_aqi_category dominant_pollutant      co    no2     o3  ...  \
# 0        Low air quality               pm25  488.99  18.79  84.07  ...
# 1       Poor air quality               pm25  489.34   8.71  89.47  ...
# 2        Low air quality                 o3  492.09  16.41  78.74  ...
# 3        Low air quality               pm25  489.48  14.84  82.55  ...
# 4        Low air quality               pm25  491.03  16.86  82.08  ...
#
#      pm25   so2                          health_general_population  \
# 0   89.18  4.21  Reduce the intensity of your outdoor activitie...
# 1  113.85  5.66  Avoid intense activities outdoors or postpone ...
# 2   45.67  3.64  Reduce the intensity of your outdoor activitie...
# 3   75.29  3.98  Reduce the intensity of your outdoor activitie...
# 4   75.09  4.18  Reduce the intensity of your outdoor activitie...
#
#                                       health_elderly  \
# 0  The current level of air quality is likely to ...
# 1  The current level of air quality is likely to ...
# 2  The current level of air quality is likely to ...
# 3  The current level of air quality is likely to ...
# 4  The current level of air quality is likely to ...
#
#                                  health_lung_disease  \
# 0  The current level of air quality is likely to ...
# 1  The current level of air quality is likely to ...
# 2  The current level of air quality is likely to ...
# 3  The current level of air quality is likely to ...
# 4  The current level of air quality is likely to ...
#
#                                 health_heart_disease  \
# 0  Avoid intense activities outdoors or postpone ...
# 1  The current level of air quality is likely to ...
# 2  Avoid intense activities outdoors or postpone ...
# 3  Avoid intense activities outdoors or postpone ...
# 4  Avoid intense activities outdoors or postpone ...
#
#                                      health_athletes  \
# 0  The current level of air quality is likely to ...
# 1  The current level of air quality is likely to ...
# 2  The current level of air quality is likely to ...
# 3  The current level of air quality is likely to ...
# 4  The current level of air quality is likely to ...
#
#                                health_pregnant_women  \
# 0  The current level of air quality is likely to ...
# 1  The current level of air quality is likely to ...
# 2  The current level of air quality is likely to ...
# 3  The current level of air quality is likely to ...
# 4  The current level of air quality is likely to ...
#
#                                      health_children      City
# 0  The current level of air quality is likely to ...  Surabaya
# 1  The current level of air quality is likely to ...  Surabaya
# 2  The current level of air quality is likely to ...  Surabaya
# 3  The current level of air quality is likely to ...  Surabaya
# 4  The current level of air quality is likely to ...  Surabaya
#
# [5 rows x 21 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import SimpleRNN, LSTM, Dense

# %%
# Pisahkan fitur (X) dan target (y)
X = df[['co', 'no2', 'o3', 'pm10','pm25','so2']]
y = df['universal_aqi']

# %%
# Pastikan y diubah menjadi array numpy sebelum reshape
y = y.values.reshape(-1, 1)

# Normalisasi data menggunakan MinMaxScaler
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X = scaler_X.fit_transform(X)
y = scaler_y.fit_transform(y)

# %%
# 5. Mengubah data menjadi bentuk sekuensial untuk RNN/LSTM (samples, timesteps, features)
timesteps = 5  # Menggunakan 5 timestep sebelumnya untuk prediksi
X_seq, y_seq = [], []
for i in range(len(X) - timesteps):
    X_seq.append(X[i:i + timesteps])
    y_seq.append(y[i + timesteps])
X_seq = np.array(X_seq)
y_seq = np.array(y_seq)

# %%
# 6. Membagi data menjadi train set dan test set
X_train, X_test, y_train, y_test = train_test_split(X_seq, y_seq, test_size=0.3, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout

rnn_model = Sequential([
    SimpleRNN(128, return_sequences=True, activation='tanh', input_shape=(timesteps, X_seq.shape[2])),
    Dropout(0.2),
    SimpleRNN(64, return_sequences=True, activation='tanh'),
    Dropout(0.2),
    SimpleRNN(32, activation='tanh'),
    Dense(10, activation='relu'),
    Dense(1, activation='linear')
])

# %%
rnn_model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
# Menambahkan callback EarlyStopping
early_stopping = EarlyStopping(
    monitor='val_loss',  # Metrik yang dipantau
    patience=10,         # Jumlah epoch tanpa peningkatan sebelum berhenti
    restore_best_weights=True  # Mengembalikan bobot terbaik
)

# %%
# Melatih model RNN dengan EarlyStopping
rnn_history = rnn_model.fit(
    X_train, y_train,
    epochs=50,  # Maksimal epoch
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[early_stopping]  # Tambahkan EarlyStopping di sini
)
# Out:
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.1265 - mae: 0.2723 - val_loss: 0.0048 - val_mae: 0.0519
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0254 - mae: 0.1254 - val_loss: 0.0052 - val_mae: 0.0536
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0131 - mae: 0.0883 - val_loss: 0.0052 - val_mae: 0.0545
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0101 - mae: 0.0772 - val_loss: 0.0034 - val_mae: 0.0454
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091 - mae: 0.0707 - val_loss: 0.0034 - val_mae: 0.0414
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077 - mae: 0.0641 - val_loss: 0.0029 - val_mae: 0.0389
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0058 - mae: 0.0559 - val_loss: 0.0033 - val_mae: 0.0400
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - mae: 0.0592 - val_loss: 0.0029 - val_mae: 0.0375
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0077 - mae: 0.0607 - val_loss: 0.0029 - val_mae: 0.0409
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - mae: 0.0510 - val_loss: 0.0027 - val_mae: 0.0370
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0053 - mae: 0.0522 - val_loss: 0.0025 - val_mae: 0.0358
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - mae: 0.0496 - val_loss: 0.0029 - val_mae: 0.0355
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - mae: 0.0492 - val_loss: 0.0030 - val_mae: 0.0361
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0052 - mae: 0.0492 - val_loss: 0.0026 - val_mae: 0.0351
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - mae: 0.0475 - val_loss: 0.0023 - val_mae: 0.0328
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047 - mae: 0.0472 - val_loss: 0.0023 - val_mae: 0.0327
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - mae: 0.0503 - val_loss: 0.0028 - val_mae: 0.0334
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037 - mae: 0.0435 - val_loss: 0.0023 - val_mae: 0.0321
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0036 - mae: 0.0427 - val_loss: 0.0025 - val_mae: 0.0321
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - mae: 0.0439 - val_loss: 0.0025 - val_mae: 0.0332
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - mae: 0.0447 - val_loss: 0.0022 - val_mae: 0.0325
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0048 - mae: 0.0473 - val_loss: 0.0027 - val_mae: 0.0345
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0053 - mae: 0.0468 - val_loss: 0.0022 - val_mae: 0.0320
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051 - mae: 0.0468 - val_loss: 0.0023 - val_mae: 0.0309
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - mae: 0.0403 - val_loss: 0.0021 - val_mae: 0.0314
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - mae: 0.0429 - val_loss: 0.0026 - val_mae: 0.0373
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - mae: 0.0437 - val_loss: 0.0022 - val_mae: 0.0315
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - mae: 0.0399 - val_loss: 0.0021 - val_mae: 0.0295
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0055 - mae: 0.0478 - val_loss: 0.0024 - val_mae: 0.0343
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mae: 0.0417 - val_loss: 0.0022 - val_mae: 0.0319
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - mae: 0.0409 - val_loss: 0.0022 - val_mae: 0.0310
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0044 - mae: 0.0421 - val_loss: 0.0022 - val_mae: 0.0344
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - mae: 0.0390 - val_loss: 0.0021 - val_mae: 0.0314
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - mae: 0.0418 - val_loss: 0.0021 - val_mae: 0.0324
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - mae: 0.0394 - val_loss: 0.0022 - val_mae: 0.0335
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043 - mae: 0.0418 - val_loss: 0.0021 - val_mae: 0.0289
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0038 - mae: 0.0400 - val_loss: 0.0019 - val_mae: 0.0287
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0038 - mae: 0.0402 - val_loss: 0.0019 - val_mae: 0.0294
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032 - mae: 0.0375 - val_loss: 0.0019 - val_mae: 0.0286
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - mae: 0.0430 - val_loss: 0.0020 - val_mae: 0.0287
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - mae: 0.0415 - val_loss: 0.0019 - val_mae: 0.0291
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0028 - mae: 0.0356 - val_loss: 0.0019 - val_mae: 0.0301
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0033 - mae: 0.0386 - val_loss: 0.0020 - val_mae: 0.0325
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031 - mae: 0.0385 - val_loss: 0.0020 - val_mae: 0.0290
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - mae: 0.0425 - val_loss: 0.0026 - val_mae: 0.0429
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0040 - mae: 0.0435 - val_loss: 0.0019 - val_mae: 0.0305
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0031 - mae: 0.0375 - val_loss: 0.0018 - val_mae: 0.0311
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - mae: 0.0422 - val_loss: 0.0022 - val_mae: 0.0326
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031 - mae: 0.0376 - val_loss: 0.0019 - val_mae: 0.0310
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - mae: 0.0401 - val_loss: 0.0018 - val_mae: 0.0290

# %%
# 11. Mengevaluasi model
rnn_loss, rnn_mae = rnn_model.evaluate(X_test, y_test)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mae: 0.0273

# %%
# 12. Menampilkan hasil evaluasi
results = {
    'RNN': {'Loss': rnn_loss, 'MAE': rnn_mae},
}

print("Hasil Evaluasi Model:")
print(results)
# Out:
# Hasil Evaluasi Model:
# {'RNN': {'Loss': 0.0017840828513726592, 'MAE': 0.029019203037023544}}

# %%
# Mengevaluasi model
rnn_loss, rnn_mae = rnn_model.evaluate(X_test, y_test)
y_test_inv = scaler_y.inverse_transform(y_test)  # Kembalikan skala asli untuk interpretasi
mae_rnn_scaled = scaler_y.inverse_transform([[rnn_mae]])[0][0]  # MAE RNN dalam skala asli
accuracy_rnn = (1 - (mae_rnn_scaled / np.mean(y_test_inv))) * 100  # Akurasi RNN dalam persentase
print("Hasil Evaluasi Model:")
print(f"RNN - Loss (MSE): {rnn_loss:.4f}, MAE: {rnn_mae:.4f}, Akurasi: {accuracy_rnn:.2f}%")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - mae: 0.0273
# Hasil Evaluasi Model:
# RNN - Loss (MSE): 0.0018, MAE: 0.0290, Akurasi: 52.08%

# %%
# Mengevaluasi model
rnn_loss, rnn_mae = rnn_model.evaluate(X_test, y_test)
# 1 - Normalized MAE
normalized_rnn_mae = rnn_mae / np.mean(y_test)  # Normalisasi MAE RNN
accuracy_rnn = 1 - normalized_rnn_mae
print("Hasil Evaluasi Model:")
print(f"RNN - Loss (MSE): {rnn_loss:.4f}, MAE: {rnn_mae:.4f}, Akurasi: {accuracy_rnn:.4f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mae: 0.0273
# Hasil Evaluasi Model:
# RNN - Loss (MSE): 0.0018, MAE: 0.0290, Akurasi: 0.9366

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Evaluasi model pada data uji
y_pred_test = rnn_model.predict(X_test)

# Inverse transform hasil prediksi dan data aktual
y_pred_test_scaled = scaler_y.inverse_transform(y_pred_test)
y_test_scaled = scaler_y.inverse_transform(y_test)

# Hitung akurasi menggunakan metrik MAE dan MSE
mae = mean_absolute_error(y_test_scaled, y_pred_test_scaled)
mse = mean_squared_error(y_test_scaled, y_pred_test_scaled)
accuracy = 1 - (mae / np.mean(y_test_scaled))  # Akurasi dalam skala 0-1

# Tampilkan akurasi
print(f"Akurasi Model (skala 0-1): {accuracy:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
# Ambil 3 input terakhir dari data uji
last_inputs = X_test[-3:]  # Mengambil 3 input terakhir
predictions = []

for _ in range(3):  # Prediksi 3 hari ke depan
    # Prediksi untuk setiap timestep
    current_input = last_inputs[-1]  # Gunakan input terakhir untuk prediksi
    prediction = rnn_model.predict(current_input.reshape(1, current_input.shape[0], current_input.shape[1]))
    predictions.append(prediction[0, 0])

    # Update input: Tambahkan prediksi terbaru sebagai langkah berikutnya
    prediction_reshaped = np.full((1, current_input.shape[1]), prediction[0, 0])  # Sesuaikan dengan fitur
    next_input = np.vstack([current_input[1:], prediction_reshaped])  # Geser dan tambahkan prediksi
    last_inputs = np.append(last_inputs[1:], [next_input], axis=0)  # Update 3 input terakhir

# Inverse transform hasil prediksi untuk kembali ke skala asli
predictions_scaled = scaler_y.inverse_transform(np.array(predictions).reshape(-1, 1))

# Output prediksi 3 hari ke depan
print("\nPrediksi 3 Hari ke Depan:")
for i, pred in enumerate(predictions_scaled.flatten(), 1):
    print(f"Hari ke-{i}: {pred:.4f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Akurasi Model (skala 0-1): 0.9647
# Mean Absolute Error (MAE): 1.5090
# Mean Squared Error (MSE): 4.8242
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Prediksi 3 Hari ke Depan:
# Hari ke-1: 36.9101
# Hari ke-2: 38.1745
# Hari ke-3: 38.8390

# %%
import matplotlib.pyplot as plt

# Visualisasi hasil prediksi vs data aktual untuk data uji
plt.figure(figsize=(12, 6))

# Plot data aktual
plt.plot(y_test_scaled.flatten(), label="Actual", color="blue", linestyle="-", marker="o", alpha=0.7)
# Plot data prediksi
plt.plot(y_pred_test_scaled.flatten(), label="Predicted", color="red", linestyle="--", marker="x", alpha=0.7)

# Tambahkan detail pada grafik
plt.title("Actual vs Predicted (Data Uji)")
plt.xlabel("Index")
plt.ylabel("Health Impact Score")
plt.legend()
plt.grid(True)

# Tampilkan grafik
plt.show()

# %%
# Fix the dimensions issue by ensuring `days` and `combined_values` have the same length

# Dummy data for demonstration (Replace with actual values)
# Assuming the last 3 actual values from y_test_scaled represent the 3 days before prediction
last_3_actual = y_test_scaled[-3:].flatten()  # Replace with the last 3 actual values
predicted_3_days = predictions_scaled.flatten()  # Replace with actual predictions for 3 days ahead

# Combine last 3 actual and 3 predicted values
combined_values = np.concatenate((last_3_actual, predicted_3_days))

# Correct `days` to match the length of `combined_values`
days = range(-3, 3)  # 3 days before (-3 to -1) and 3 days ahead (0 to 2)

# Visualisasi
plt.figure(figsize=(12, 6))
plt.plot(days, combined_values, label="Combined Actual and Predicted", linestyle='-', marker='o', color='green')

# Highlight the split between actual and predicted
plt.axvline(x=-0.5, color='gray', linestyle='--', label="Split (Actual vs Predicted)")

# Tambahkan detail pada grafik
plt.title("3 Days Before vs 3 Days Ahead Predictions")
plt.xlabel("Day (Relative to Current)")
plt.ylabel("Health Impact Score")
plt.xticks(days)
plt.legend()
plt.grid(True)

# Tampilkan grafik
plt.show()

# %%
rnn_model.export("rnnModel")
# Out:
# INFO:tensorflow:Assets written to: rnnModel\assets
# INFO:tensorflow:Assets written to: rnnModel\assets
# Saved artifact at 'rnnModel'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 5, 6), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   1887733032208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1887733033936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1887733032976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1887733033360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1887733032784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1887733033552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1887733034896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1887733034704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1887733035088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1887733034128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1887733035856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1887733036048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1887733037008: TensorSpec(shape=(), dtype=tf.resource, name=None)
